# %%
from bs4 import BeautifulSoup
import requests
import json

# %%
response = requests.get("https://www.imsnsit.org/imsnsit/notifications.php")

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <title>NSUT NOTICES / CIRCULARS</title><link href="css/METAL/app.css" rel="stylesheet" type="text/css"/>
# <script language="javascript" src="js/plumjs.js" type="text/javascript"> </script><style>
# 	td{padding-left:5px;font-size:13px;}
# 	td input,textarea{padding:0 5px;}
# 	td select{width:100px;padding:5px;}
# 	td input[type='submit']{border:1px solid #f1f1f1;border-radius:0px;font-size:15px;cursor:pointer;}
# 	td input[type='text'],[type='email']{padding:5px;}
# 	button {
# 		background-color: greay; /* Green */
# 		border: none;
# 		color: black;
# 		text-align: center;
# 		text-decoration: none;
# 		display: inline-block;
# 		font-size: 16px;
# 		margin: 4px 2px;
# 		cursor: pointer;
# 	}
# 	</style><div align="center" valign="center"><br/><a class="button" href="https://imsnsit.org/imsnsit"><font size="4">GO TO NSUTIMS LOGIN PAGE</font></a><br/><br/></div><table align="center" border="0" cellpadding="3" cellspacing="0" style="border-collapse:collapse;border: 0px solid black;" width="80%">
# <tr><td align="right"><a class="button" href="https://drive.google.com/drive/folders/1gExYdi_eFnBgl5AE2QxyJ0H7CVJbfd0Z" target="_BLANK"><font size="3">Daily Biometric Attendance</font></a></td></tr></table><form method="post"><table align="center" border="0" cellpadding="3" cellspacing="0" style="border-collapse:collapse;border: 1px solid black;" width="80%">
# <tr><td><img border="0" height="100" src="https://www.imsnsit.org/imsnsit/plum_url.php?pQfruFgGe/vfHWYDzShqlX38e5c/uyeFLrpyOXIufsvI0NEJ3BBLfr9WA0Adbo4zhGbQcLWs10lLlKcyhAW1EU1iQ6xKhE0wY+gEJ3sPN41ayNRH7IqMsPNRAX9ymgpgxkNwImeTvu/n1ly7KJTFDA==" width="100"/></td>
# <td align="center" colspan="2" nowrap="" width="70%"><font face="tahoma" size="5"><b>
# 		NETAJI SUBHAS UNIVERSITY OF TECHNOLOGY</b></font><br/><font face="tahoma" size="3">AZAD HIND FAUJ MARG, SECTOR-3, DWARKA </font><br/><font face="tahoma" size="3">NEW DELHI - 110078. </font></td></tr>
# <tr class="plum_head"><td align="center" colspan="3"><font size="3">   NOTICES / CIRCULARS</font><div style="float:right"> Department :<select caption="" class="plum_combo" id="branch" mandatory="0" name="branch" style="width:150px;"><option value=""> Select ...</option><option selected="" value="All">All</option><option value="ACADEMIC SECTION">ACADEMIC SECTION</option><option value="ACADEMIC SECTION PG">ACADEMIC SECTION PG</option><option value="ACADEMIC SECTION UG">ACADEMIC SECTION UG</option><option value="ACCOUNTS SECTION">ACCOUNTS SECTION</option><option value="ADMISSION OFFICE">ADMISSION OFFICE</option><option value="APPLIED SCIENCES AND HUMANITIES">APPLIED SCIENCES AND HUMANITIES (WEST)</option><option value="Architecture">Architecture</option><option value="ARCHITECTURE AND PLANNING">ARCHITECTURE AND PLANNING</option><option value="BE ADMISSION CELL">BE ADMISSION CELL</option><option value="BIO TECHNOLOGY">BIO TECHNOLOGY</option><option value="BIOLOGICAL SCIENCES AND ENGINEERING">BIOLOGICAL SCIENCES AND ENGINEERING</option><option value="CENTRAL COMPUTER CENTER">CENTRAL COMPUTER CENTER</option><option value="CENTRE OF EXCELLENCE IN ARTIFICIAL INTELLIGENCE">CENTRE OF EXCELLENCE IN ARTIFICIAL INTELLIGENCE</option><option value="CHEMISTRY">CHEMISTRY</option><option value="CIMS">CIMS</option><option value="CIVIL ENGINEERING">CIVIL ENGINEERING</option><option value="Civil Engineering / Geo Informatics">Civil Engineering / Geo Informatics</option><option value="CLINIC">CLINIC</option><option value="COMPUTER ENGINEERING">COMPUTER ENGINEERING</option><option value="COMPUTER SCIENCE AND ENGINEERING">COMPUTER SCIENCE AND ENGINEERING</option><option value="Computer Science and Engineering / Information Technology">Computer Science and Engineering / Information Technology</option><option value="COMPUTER SCIENCE AND ENGINEERING(EAST)">COMPUTER SCIENCE AND ENGINEERING(EAST)</option><option value="DEAN PG STUDIES">DEAN PG STUDIES</option><option value="DEAN STUDENT WELFARE OFFICE">DEAN STUDENT WELFARE OFFICE</option><option value="DEAN UG STUDIES">DEAN UG STUDIES</option><option value="DESIGN">DESIGN</option><option value="DIRECTOR OFFICE">DIRECTOR OFFICE</option><option value="DUMMY">DUMMY</option><option value="EAST CAMPUS">EAST CAMPUS</option><option value="ELECTRICAL ENGINEERING">ELECTRICAL ENGINEERING</option><option value="ELECTRONICS AND COMMUNICATION ENGINEERING">ELECTRONICS AND COMMUNICATION ENGINEERING</option><option value="ELECTRONICS AND COMMUNICATION ENGINEERING(EAST)">ELECTRONICS AND COMMUNICATION ENGINEERING(EAST)</option><option value="ENGINEERING CELL">ENGINEERING CELL</option><option value="ECEC">ENGINEERING CELL EAST CAMPUS</option><option value="ECWC">ENGINEERING CELL WEST CAMPUS</option><option value="English">English</option><option value="ESTABLISHMENT SECTION">ESTABLISHMENT SECTION</option><option value="EXAMINATION CELL">EXAMINATION CELL</option><option value="EXAMINATION SECTION">EXAMINATION SECTION</option><option value="FACULTY OF ARCHITECTURE AND DESIGN">FACULTY OF ARCHITECTURE AND DESIGN</option><option value="FACULTY OF ELECTRICAL AND MECHANICAL ENGINEERING">FACULTY OF ELECTRICAL AND MECHANICAL ENGINEERING</option><option value="FHSS">FACULTY OF HUMANITIES AND SOCIAL SCIENCES</option><option value="FICT">FACULTY OF INFORMATION AND COMMUNICATION TECHNOLOGY</option><option value="FACULTY OF INFORMATION AND COMMUNICATION TECHNOLOGY">FACULTY OF INFORMATION AND COMMUNICATION TECHNOLOGY</option><option value="FIDS">FACULTY OF INTER DISCIPLINARY STUDIES</option><option value="FMS">FACULTY OF MANAGEMENT STUDIES</option><option value="FACULTY OF SCIENCES">FACULTY OF SCIENCES</option><option value="GEOINFORMATICS">GEOINFORMATICS</option><option value="GUEST HOUSE">GUEST HOUSE</option><option value="HEALTH CENTER">HEALTH CENTER</option><option value="HOSTEL">HOSTEL</option><option value="HUMANITIES AND SOCIAL SCIENCES">HUMANITIES AND SOCIAL SCIENCES</option><option value="INFORMATION TECHNOLOGY">INFORMATION TECH ...
# <input id="enc_branch" name="enc_branch" type="hidden" value="..."/> <input name="submit" type="submit" value="Submit"/></div></td></tr></table></form><tr class="plum_head"><td nowrap="" style="padding:5px;line-height:30px;font-size:18px;font-weight:600;background:#eee;"><b>Date</b></td><td colspan="2" style="padding:5px;line-height:30px;font-size:18px;font-weight:600;background:#eee;"><b>Subject</b></td></tr><tr><td nowrap=""><font size="3">09-08-2025 <img src="images/newicon.gif"/></font></td><td class="list-data-focus" colspan="2"><a href="https://www.imsnsit.org/imsnsit/plum_url.php?x5fBuMev9OTWA0RAxdGyhqXVW9PYe86misTv3gSSQvNXrPVqIYBkTd+/UNsYxPyF0LcKngfLDPLs2OKRYvnt2lOh6ijQMb3Mq3BQE6xqoF3KuClLUpoXDyYy1lLFKypi5v/JQmoc3zkUIitvjfd8FaOwr4W/eK95+7TLL4UmsiyPUYTKvVGe6cIfPPmlCoMm71jQcXhK5RKYUMutSx4GLQ==" style="text-decoration:none;" target="_BLANK" title="NOTICES / CIRCULARS"><font size="3">Warning regarding unauthorized Fresher party</font></a><br/><font size="1"><br/><b>Published By:  SONIKA BHATNAGAR, PROFESSOR, PROCTOR OFFICE</b></font></td></tr><tr><td colspan="3"><hr/></td></tr><tr><td nowrap=""><font size="3">08-08-2025 <img src="images/newicon.gif"/></font></td><td class="list-data-focus" colspan="2"><a href="https://www.imsnsit.org/imsnsit/plum_url.php?+5tmDTeP5vRWOGvGgK0DTmxVOuJjdEkFyZFQSlZEDKfM0tTzeeg4Bhb89v5oiZWNbOTAmUVTCdOFWsWYinye9tmAjFlFU/o56yKbk4Pjm+uM2JVz2o/hP3VF7TjRrE9aTleihSyr0J7HNXtpl39EVj16fCUDP6LmkNLjp2Dv68ifgRLIv9m8TXvd37XfoU9J" style="text-decoration:none;" target="_BLANK" title="NOTICES / CIRCULARS"><font size="3">Interview Schedule for Festival Resonanz 2025 – Team Selection</font></a><br/><font size="1"><br/><b>Published By:  AJAY KUMAR KATARIA, ASSISTANT PROFESSOR, DEAN STUDENT WELFARE OFFICE</b></font></td></tr><tr><td colspan="3"><hr/></td></tr><tr><td nowrap=""><font size="3">08-08-2025 <img src="images/newicon.gif"/></font></td><td class="list-data-focus" colspan="2"><a href="https://www.imsnsit.org/imsnsit/plum_url.php?" style="text-decoration:none;" target="_BLANK" title="NOTICES / CIRCULARS"><font size="3">Balance fee  submission for newly admitted Ist year MBA student</font></a><br/><font size="1"><br/><b>Published By: DR DINESH KUMAR, ASSISTANT PROFESSOR, MANAGEMENT STUDIES</b></font></td></tr><tr><td colspan="3"><hr/></td></tr><tr><td nowrap=""><font size="3">08-08-2025 <img src="images/newicon.gif"/></font></td><td colspan="2"><a class="list-data-focus" href="https://drive.google.com/file/d/103uCTot1X8uBoUpDwGSHrdCiBWQnuPC9/view?usp=sharing" style="text-decoration:none;" target="_BLANK" title="NOTICES / CIRCULARS"><font size="3">Notification: Remuneration of guest faculty at NSUT West Campus for teaching in a semester.</font></a><br/><font size="1"><br/><b>Published By:  , CENTRAL COMPUTER CENTER</b></font></td></tr><tr><td colspan="3"><hr/></td></tr><tr><td nowrap=""><font size="3">08-08-2025 <img src="images/newicon.gif"/></font></td><td class="list-data-focus" colspan="2"><a href="https://www.imsnsit.org/imsnsit/plum_url.php?Rk+Ht07FnwYTdxgh9d2B0RydF6rQe3R01l/UEoEfGhRUc/hKBcvIGe3ulrFs0ki03+xl4riCVjXskGymZ4Tyomi5jK1cVq4mOxWz7B6jA/1IduBJIGzAYbNpAzr2xVZB4UeffY+X05SbW9s0tWF0CGj2XhvubUtKYgP2o7A2Y0V6jzqqDSdjt+4mWU/LYP460wkc2Mlz1eP88g/S12yYHiRrpxVT/y7BdesVPYCmtto=" style="text-decoration:none;" target="_BLANK" title="NOTICES / CIRCULARS"><font size="3">Notice-Community Internship for third semester students</font></a><br/><font size="1"><br/><b>Published By:  PREETI KAUR, PROFESSOR, COMPUTER SCIENCE AND ENGINEERING</b></font></td></tr><tr><td colspan="3"><hr/></td></tr><tr><td nowrap=""><font size="3">07-08-2025 <img src="images/newicon.gif"/></font></td><td class="list-data-focus" colspan="2"><a href="https://www.imsnsi ...

# %%
from pydantic import BaseModel
from typing import Optional

class Notice(BaseModel):
    date: str
    title: str
    notice_url: str
    published_by: Optional[str] = None
    department: Optional[str]=None

# %%
def fetch_notice():
    
    all_notices = []

    for row in soup.find_all('tr'):
        a = row.find('a')
        if a:
            try:
                # Extract data
                title = a.text.strip()
                link = a['href']
                date = row.find('td').text.strip().split()[0]

                # Safely extract 'Published By' information
                b_tags = row.find_all('b')
                publisher_info = b_tags[-1].text.replace("Published By:", "").strip().split(",")
                
                published_by = publisher_info[0].strip()
                # Handle cases where department might be the same as publisher
                department = publisher_info[-1].strip() if len(publisher_info) > 1 else published_by

                # Create a dictionary for the current notice
                # The keys match your Pydantic model for easy integration
                notice_dict = {
                    "date": date,
                    "title": title,
                    "notice_url": link,
                    "published_by": published_by,
                    "department": department
                }

                # Add the dictionary to our list
                all_notices.append(notice_dict)

            except (IndexError, AttributeError) as e:
                # This will catch errors if 'b_tags' is empty, 'a' is missing,
                # or other parsing issues occur.
                # print(f"Skipping a row due to parsing error: {e}")
                continue

    # json_output = json.dumps(all_notices, indent=4)
    return all_notices

output = fetch_notice()
print(output)
# Out:
# [{'date': '09-08-2025', 'title': 'Warning regarding unauthorized Fresher party', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?x5fBuMev9OTWA0RAxdGyhqXVW9PYe86misTv3gSSQvNXrPVqIYBkTd+/UNsYxPyF0LcKngfLDPLs2OKRYvnt2lOh6ijQMb3Mq3BQE6xqoF3KuClLUpoXDyYy1lLFKypi5v/JQmoc3zkUIitvjfd8FaOwr4W/eK95+7TLL4UmsiyPUYTKvVGe6cIfPPmlCoMm71jQcXhK5RKYUMutSx4GLQ==', 'published_by': 'SONIKA BHATNAGAR', 'department': 'PROCTOR OFFICE'}, {'date': '08-08-2025', 'title': 'Interview Schedule for Festival Resonanz 2025 – Team Selection', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?+5tmDTeP5vRWOGvGgK0DTmxVOuJjdEkFyZFQSlZEDKfM0tTzeeg4Bhb89v5oiZWNbOTAmUVTCdOFWsWYinye9tmAjFlFU/o56yKbk4Pjm+uM2JVz2o/hP3VF7TjRrE9aTleihSyr0J7HNXtpl39EVj16fCUDP6LmkNLjp2Dv68ifgRLIv9m8TXvd37XfoU9J', 'published_by': 'AJAY KUMAR KATARIA', 'department': 'DEAN STUDENT WELFARE OFFICE'}, {'date': '08-08-2025', 'title': 'Balance fee  submission for newly admitted Ist year MBA student', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?', 'published_by': 'DR DINESH KUMAR', 'department': 'MANAGEMENT STUDIES'}, {'date': '08-08-2025', 'title': 'Notification: Remuneration of guest faculty at NSUT West Campus for teaching in a semester.', 'notice_url': 'https://drive.google.com/file/d/103uCTot1X8uBoUpDwGSHrdCiBWQnuPC9/view?usp=sharing', 'published_by': '', 'department': 'CENTRAL COMPUTER CENTER'}, {'date': '08-08-2025', 'title': 'Notice-Community Internship for third semester students', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?Rk+Ht07FnwYTdxgh9d2B0RydF6rQe3R01l/UEoEfGhRUc/hKBcvIGe3ulrFs0ki03+xl4riCVjXskGymZ4Tyomi5jK1cVq4mOxWz7B6jA/1IduBJIGzAYbNpAzr2xVZB4UeffY+X05SbW9s0tWF0CGj2XhvubUtKYgP2o7A2Y0V6jzqqDSdjt+4mWU/LYP460wkc2Mlz1eP88g/S12yYHiRrpxVT/y7BdesVPYCmtto=', 'published_by': 'PREETI KAUR', 'department': 'COMPUTER SCIENCE AND ENGINEERING'}, {'date': '07-08-2025', 'title': 'NOTIFICATION-II (REJECTED) DELHI HIGHER & TECHNICAL EDUCATION SUPPORT SCHEME SCHOLARSHIP', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?Oc5OYQqv8l6gpdx+gXVxwZXW4nzOX2iskK38zFIc7avR4LvGIb9Kj+sRp37EHcPZljqT2LdEQ2YcoD0WkUZChCvPH58CDYWMFgzYpLXQDiY1NuheOP8j4q085iqFa5TlPng+TfimtjAAlPgkjhvvAdGIdMZgtgiEEugUR4oolP0q7xDLtq679VQmVpP6ITCa3Vw8K///Y2CytJ0vS53UlA==', 'published_by': 'TARUNA TIWARI', 'department': 'ACADEMIC SECTION'}, {'date': '07-08-2025', 'title': 'NOTIFICATION-I (DISCREPANCY) DELHI HIGHER & TECHNICAL EDUCATION SUPPORT SCHEME SCHOLARSHIP', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?Ru4Ivbw1GuPSNjST0mp/TiWjsyHIRgM3169DDxh6sOFECPaci2rHFK8/ijG7Es7apOAj2LGC7suzen5BeBHf4+D4Cpwp3yCc/BMMe9rBLAt/yFogiagKh/zf+n/2hzC1xUxN8QngCT9gGpAIJEZ1YRREEXHV/vhwhOtx+wJJEFgZLSCuVPPbRulbJA6KfNxbTw/frZVwQ6P3q8l71klAUg==', 'published_by': 'TARUNA TIWARI', 'department': 'ACADEMIC SECTION'}, {'date': '07-08-2025', 'title': 'Admission Cancellation of newly admitted students who have neither reported nor paid the Balance Fee (2025-26)', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?', 'published_by': 'TARUN KUMAR RAWAT', 'department': 'ADMISSION OFFICE'}, {'date': '06-08-2025', 'title': 'Submission of BTP-I (ECAM-1 & 2 )Consent form for the academic session 2025-2026', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?0c3E6dMhkLYnpFVkgrsETAzeU5EKsT++PDXoBJAdNvrWluQV7iEy+zDzd25hT5Xbrd9VbkqA7wJsvuZxNRVx8zMkoFianlAsLzQT32mWVZrmVxN3anOVtpuPKsXO8CMNWdbN0nEREVIv8VdhHZrC8N+qYk6qKDEgh4/VeqyKIW8qmfaSzpKwM/s4twlRr6t39GoBhd8+fd ...

# %%
# Learn pymongo, CRUD & other operations
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in ./.venv/lib/python3.12/site-packages (4.13.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./.venv/lib/python3.12/site-packages (from pymongo) (2.7.0)

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb+srv://admin:asdf%401234@ping.uskhf3w.mongodb.net/")

mydb = myclient["learnDB"]
mycol = mydb["Test_1"]

# %%
print(myclient.list_database_names())
# Out:
# ['Notice_data', 'learnDB', 'sample_mflix', 'admin', 'local']

# %% [markdown]
# ## INSERT

# %%
# INSERTION INTO COLLECTION
import pymongo

mydict = { "name": "John", "address": "Highway 37" }

x = mycol.insert_one(mydict)

# %%
# print(myclient.list_database_names())
x.inserted_id
# Out:
# ObjectId('68986d9a048a80f8aeeaa2d8')

# %% [markdown]
# ## READ

# %%
x = mycol.find()

for document in x:
    print(document)
# Out:
# {'_id': ObjectId('688f0959fe58d60830fc908d'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('688f095afe58d60830fc908e'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('688f0a13fe58d60830fc908f'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('688f0a13fe58d60830fc9090'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('688f0a13fe58d60830fc9094'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('688f0a13fe58d60830fc9095'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('688f0a13fe58d60830fc9092'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('688f0a13fe58d60830fc9096'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('688f0a13fe58d60830fc9091'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('688f0a13fe58d60830fc9093'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('688f0a13fe58d60830fc9098'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('688f0a13fe58d60830fc9099'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('688f0a13fe58d60830fc9097'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('688f0a13fe58d60830fc909a'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('688f0a26fe58d60830fc909c'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('688f0a26fe58d60830fc909e'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('688f0a26fe58d60830fc909f'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a2'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('688f0a26fe58d60830fc909b'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('688f0a26fe58d60830fc909d'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a4'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a3'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a0'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a1'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a5'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a6'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': 10, 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': 12, 'name': 'William', 'address': 'Central st 954'}
# {'_id': 1, 'name': 'John', 'address': 'Highway 37'}
# {'_id': 7, 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': 13, 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': 2, 'name': 'Peter', 'address': 'Lowstreet 27'}
# {'_id': 6, 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': 3, 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': 4, 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': 5, 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': 8, 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': 9, 'name': 'Susan', 'address': 'One way 98'}
# {'_id': 11, 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': 14, 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2d8'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2d9'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2da'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2db'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2dc'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2dd'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2de'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2df'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2e0'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2e1'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2e2'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2e3'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2e4'), 'name': 'Viola', 'address': 'Sideway 1633'}

# %%
for x in mycol.find({},{ "_id": 0, "name": 1, "address": 1 }):
  print(x)
# Out:
# {'name': 'John', 'address': 'Highway 37'}
# {'name': 'John', 'address': 'Highway 37'}
# {'name': 'Amy', 'address': 'Apple st 652'}
# {'name': 'Hannah', 'address': 'Mountain 21'}
# {'name': 'Richard', 'address': 'Sky st 331'}
# {'name': 'Susan', 'address': 'One way 98'}
# {'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'name': 'Michael', 'address': 'Valley 345'}
# {'name': 'Betty', 'address': 'Green Grass 1'}
# {'name': 'William', 'address': 'Central st 954'}
# {'name': 'Chuck', 'address': 'Main Road 989'}
# {'name': 'Ben', 'address': 'Park Lane 38'}
# {'name': 'Viola', 'address': 'Sideway 1633'}
# {'name': 'Hannah', 'address': 'Mountain 21'}
# {'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'name': 'Betty', 'address': 'Green Grass 1'}
# {'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'name': 'Amy', 'address': 'Apple st 652'}
# {'name': 'Michael', 'address': 'Valley 345'}
# {'name': 'William', 'address': 'Central st 954'}
# {'name': 'Ben', 'address': 'Park Lane 38'}
# {'name': 'Richard', 'address': 'Sky st 331'}
# {'name': 'Susan', 'address': 'One way 98'}
# {'name': 'Chuck', 'address': 'Main Road 989'}
# {'name': 'Viola', 'address': 'Sideway 1633'}
# {'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'name': 'William', 'address': 'Central st 954'}
# {'name': 'John', 'address': 'Highway 37'}
# {'name': 'Betty', 'address': 'Green Grass 1'}
# {'name': 'Chuck', 'address': 'Main Road 989'}
# {'name': 'Peter', 'address': 'Lowstreet 27'}
# {'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'name': 'Amy', 'address': 'Apple st 652'}
# {'name': 'Hannah', 'address': 'Mountain 21'}
# {'name': 'Michael', 'address': 'Valley 345'}
# {'name': 'Richard', 'address': 'Sky st 331'}
# {'name': 'Susan', 'address': 'One way 98'}
# {'name': 'Ben', 'address': 'Park Lane 38'}
# {'name': 'Viola', 'address': 'Sideway 1633'}
# {'name': 'John', 'address': 'Highway 37'}
# {'name': 'Amy', 'address': 'Apple st 652'}
# {'name': 'Hannah', 'address': 'Mountain 21'}
# {'name': 'Michael', 'address': 'Valley 345'}
# {'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'name': 'Betty', 'address': 'Green Grass 1'}
# {'name': 'Richard', 'address': 'Sky st 331'}
# {'name': 'Susan', 'address': 'One way 98'}
# {'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'name': 'Ben', 'address': 'Park Lane 38'}
# {'name': 'William', 'address': 'Central st 954'}
# {'name': 'Chuck', 'address': 'Main Road 989'}
# {'name': 'Viola', 'address': 'Sideway 1633'}

# %%
for x in mycol.find({},{ "name":1, "address": 1}):
  print(x)
# Out:
# {'_id': ObjectId('688f0959fe58d60830fc908d'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('688f095afe58d60830fc908e'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('688f0a13fe58d60830fc908f'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('688f0a13fe58d60830fc9090'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('688f0a13fe58d60830fc9094'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('688f0a13fe58d60830fc9095'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('688f0a13fe58d60830fc9092'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('688f0a13fe58d60830fc9096'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('688f0a13fe58d60830fc9091'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('688f0a13fe58d60830fc9093'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('688f0a13fe58d60830fc9098'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('688f0a13fe58d60830fc9099'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('688f0a13fe58d60830fc9097'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('688f0a13fe58d60830fc909a'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('688f0a26fe58d60830fc909c'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('688f0a26fe58d60830fc909e'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('688f0a26fe58d60830fc909f'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a2'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('688f0a26fe58d60830fc909b'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('688f0a26fe58d60830fc909d'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a4'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a3'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a0'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a1'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a5'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a6'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': 10, 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': 12, 'name': 'William', 'address': 'Central st 954'}
# {'_id': 1, 'name': 'John', 'address': 'Highway 37'}
# {'_id': 7, 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': 13, 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': 2, 'name': 'Peter', 'address': 'Lowstreet 27'}
# {'_id': 6, 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': 3, 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': 4, 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': 5, 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': 8, 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': 9, 'name': 'Susan', 'address': 'One way 98'}
# {'_id': 11, 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': 14, 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2d8'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2d9'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2da'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2db'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2dc'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2dd'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2de'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2df'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2e0'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2e1'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2e2'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2e3'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2e4'), 'name': 'Viola', 'address': 'Sideway 1633'}

# %% [markdown]
# ## FIND

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb+srv://admin:asdf%401234@ping.uskhf3w.mongodb.net/")

mydb = myclient["learnDB"]
mycol = mydb["Test_1"]

myquery = { "address": "One way 98" }

mydoc = mycol.find(myquery)

for x in mydoc:
  print(x)
# Out:
# {'_id': ObjectId('688f0a13fe58d60830fc9095'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('688f0a26fe58d60830fc90a1'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': 9, 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('68986d9a048a80f8aeeaa2df'), 'name': 'Susan', 'address': 'One way 98'}

# %% [markdown]
# # Push to Mongo

# %%
scraped_notices = fetch_notice()
print(scraped_notices)
# Out:
# [{'date': '09-08-2025', 'title': 'Warning regarding unauthorized Fresher party', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?x5fBuMev9OTWA0RAxdGyhqXVW9PYe86misTv3gSSQvNXrPVqIYBkTd+/UNsYxPyF0LcKngfLDPLs2OKRYvnt2lOh6ijQMb3Mq3BQE6xqoF3KuClLUpoXDyYy1lLFKypi5v/JQmoc3zkUIitvjfd8FaOwr4W/eK95+7TLL4UmsiyPUYTKvVGe6cIfPPmlCoMm71jQcXhK5RKYUMutSx4GLQ==', 'published_by': 'SONIKA BHATNAGAR', 'department': 'PROCTOR OFFICE'}, {'date': '08-08-2025', 'title': 'Interview Schedule for Festival Resonanz 2025 – Team Selection', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?+5tmDTeP5vRWOGvGgK0DTmxVOuJjdEkFyZFQSlZEDKfM0tTzeeg4Bhb89v5oiZWNbOTAmUVTCdOFWsWYinye9tmAjFlFU/o56yKbk4Pjm+uM2JVz2o/hP3VF7TjRrE9aTleihSyr0J7HNXtpl39EVj16fCUDP6LmkNLjp2Dv68ifgRLIv9m8TXvd37XfoU9J', 'published_by': 'AJAY KUMAR KATARIA', 'department': 'DEAN STUDENT WELFARE OFFICE'}, {'date': '08-08-2025', 'title': 'Balance fee  submission for newly admitted Ist year MBA student', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?', 'published_by': 'DR DINESH KUMAR', 'department': 'MANAGEMENT STUDIES'}, {'date': '08-08-2025', 'title': 'Notification: Remuneration of guest faculty at NSUT West Campus for teaching in a semester.', 'notice_url': 'https://drive.google.com/file/d/103uCTot1X8uBoUpDwGSHrdCiBWQnuPC9/view?usp=sharing', 'published_by': '', 'department': 'CENTRAL COMPUTER CENTER'}, {'date': '08-08-2025', 'title': 'Notice-Community Internship for third semester students', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?Rk+Ht07FnwYTdxgh9d2B0RydF6rQe3R01l/UEoEfGhRUc/hKBcvIGe3ulrFs0ki03+xl4riCVjXskGymZ4Tyomi5jK1cVq4mOxWz7B6jA/1IduBJIGzAYbNpAzr2xVZB4UeffY+X05SbW9s0tWF0CGj2XhvubUtKYgP2o7A2Y0V6jzqqDSdjt+4mWU/LYP460wkc2Mlz1eP88g/S12yYHiRrpxVT/y7BdesVPYCmtto=', 'published_by': 'PREETI KAUR', 'department': 'COMPUTER SCIENCE AND ENGINEERING'}, {'date': '07-08-2025', 'title': 'NOTIFICATION-II (REJECTED) DELHI HIGHER & TECHNICAL EDUCATION SUPPORT SCHEME SCHOLARSHIP', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?Oc5OYQqv8l6gpdx+gXVxwZXW4nzOX2iskK38zFIc7avR4LvGIb9Kj+sRp37EHcPZljqT2LdEQ2YcoD0WkUZChCvPH58CDYWMFgzYpLXQDiY1NuheOP8j4q085iqFa5TlPng+TfimtjAAlPgkjhvvAdGIdMZgtgiEEugUR4oolP0q7xDLtq679VQmVpP6ITCa3Vw8K///Y2CytJ0vS53UlA==', 'published_by': 'TARUNA TIWARI', 'department': 'ACADEMIC SECTION'}, {'date': '07-08-2025', 'title': 'NOTIFICATION-I (DISCREPANCY) DELHI HIGHER & TECHNICAL EDUCATION SUPPORT SCHEME SCHOLARSHIP', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?Ru4Ivbw1GuPSNjST0mp/TiWjsyHIRgM3169DDxh6sOFECPaci2rHFK8/ijG7Es7apOAj2LGC7suzen5BeBHf4+D4Cpwp3yCc/BMMe9rBLAt/yFogiagKh/zf+n/2hzC1xUxN8QngCT9gGpAIJEZ1YRREEXHV/vhwhOtx+wJJEFgZLSCuVPPbRulbJA6KfNxbTw/frZVwQ6P3q8l71klAUg==', 'published_by': 'TARUNA TIWARI', 'department': 'ACADEMIC SECTION'}, {'date': '07-08-2025', 'title': 'Admission Cancellation of newly admitted students who have neither reported nor paid the Balance Fee (2025-26)', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?', 'published_by': 'TARUN KUMAR RAWAT', 'department': 'ADMISSION OFFICE'}, {'date': '06-08-2025', 'title': 'Submission of BTP-I (ECAM-1 & 2 )Consent form for the academic session 2025-2026', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?0c3E6dMhkLYnpFVkgrsETAzeU5EKsT++PDXoBJAdNvrWluQV7iEy+zDzd25hT5Xbrd9VbkqA7wJsvuZxNRVx8zMkoFianlAsLzQT32mWVZrmVxN3anOVtpuPKsXO8CMNWdbN0nEREVIv8VdhHZrC8N+qYk6qKDEgh4/VeqyKIW8qmfaSzpKwM/s4twlRr6t39GoBhd8+fd ...

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

mylist = [
  { "name": "Amy", "address": "Apple st 652"},
  { "name": "Hannah", "address": "Mountain 21"},
  { "name": "Michael", "address": "Valley 345"},
  { "name": "Sandy", "address": "Ocean blvd 2"},
  { "name": "Betty", "address": "Green Grass 1"},
  { "name": "Richard", "address": "Sky st 331"},
  { "name": "Susan", "address": "One way 98"},
  { "name": "Vicky", "address": "Yellow Garden 2"},
  { "name": "Ben", "address": "Park Lane 38"},
  { "name": "William", "address": "Central st 954"},
  { "name": "Chuck", "address": "Main Road 989"},
  { "name": "Viola", "address": "Sideway 1633"}
]

x = mycol.insert_many(mylist)

#print list of the _id values of the inserted documents:
print(x.inserted_ids)
# Out:
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c3f048a80f8aeeaa39b') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c3f048a80f8aeeaa39b') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c3f048a80f8aeeaa39b')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa39e') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa39e') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa39e')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa39f') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa39f') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa39f')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a0') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a0') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3a0')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a1') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a1') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3a1')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a2') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a2') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3a2')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a3') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a3') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3a3')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a4') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a4') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3a4')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a5') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a5') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3a5')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a6') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a6') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3a6')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a7') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a7') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3a7')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a8') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a8') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3a8')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a9') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3a9') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3a9')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3aa') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3aa') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3aa')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3ab') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3ab') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3ab')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3ac') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3ac') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3ac')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3ad') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3ad') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3ad')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3ae') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3ae') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3ae')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3af') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3af') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3af')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3b0') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3b0') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3b0')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3b1') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3b1') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3b1')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3b2') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3b2') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3b2')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3b3') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3b3') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3b3')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3b4') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c71048a80f8aeeaa3b4') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c71048a80f8aeeaa3b4')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3b5') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3b5') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3b5')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3b6') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3b6') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3b6')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3b7') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3b7') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3b7')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3b8') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3b8') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3b8')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3b9') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3b9') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3b9')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3ba') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3ba') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3ba')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3bb') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3bb') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3bb')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3bc') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3bc') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3bc')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3bd') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3bd') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3bd')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3be') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3be') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3be')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3bf') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3bf') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3bf')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c0') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c0') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3c0')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c1') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c1') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3c1')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c2') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c2') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3c2')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c3') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c3') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3c3')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c4') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c4') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3c4')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c5') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c5') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3c5')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c6') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c6') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3c6')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c7') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c7') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3c7')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c8') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c8') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3c8')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c9') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3c9') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3c9')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3ca') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3ca') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3ca')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3cb') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3cb') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3cb')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3cc') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3cc') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3cc')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3cd') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3cd') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3cd')}}
# [E]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3ce') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c72048a80f8aeeaa3ce') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c72048a80f8aeeaa3ce')}}

# %%
scraped_notices = fetch_notice()
print(scraped_notices)
# Out:
# [{'date': '09-08-2025', 'title': 'Warning regarding unauthorized Fresher party', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?x5fBuMev9OTWA0RAxdGyhqXVW9PYe86misTv3gSSQvNXrPVqIYBkTd+/UNsYxPyF0LcKngfLDPLs2OKRYvnt2lOh6ijQMb3Mq3BQE6xqoF3KuClLUpoXDyYy1lLFKypi5v/JQmoc3zkUIitvjfd8FaOwr4W/eK95+7TLL4UmsiyPUYTKvVGe6cIfPPmlCoMm71jQcXhK5RKYUMutSx4GLQ==', 'published_by': 'SONIKA BHATNAGAR', 'department': 'PROCTOR OFFICE'}, {'date': '08-08-2025', 'title': 'Interview Schedule for Festival Resonanz 2025 – Team Selection', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?+5tmDTeP5vRWOGvGgK0DTmxVOuJjdEkFyZFQSlZEDKfM0tTzeeg4Bhb89v5oiZWNbOTAmUVTCdOFWsWYinye9tmAjFlFU/o56yKbk4Pjm+uM2JVz2o/hP3VF7TjRrE9aTleihSyr0J7HNXtpl39EVj16fCUDP6LmkNLjp2Dv68ifgRLIv9m8TXvd37XfoU9J', 'published_by': 'AJAY KUMAR KATARIA', 'department': 'DEAN STUDENT WELFARE OFFICE'}, {'date': '08-08-2025', 'title': 'Balance fee  submission for newly admitted Ist year MBA student', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?', 'published_by': 'DR DINESH KUMAR', 'department': 'MANAGEMENT STUDIES'}, {'date': '08-08-2025', 'title': 'Notification: Remuneration of guest faculty at NSUT West Campus for teaching in a semester.', 'notice_url': 'https://drive.google.com/file/d/103uCTot1X8uBoUpDwGSHrdCiBWQnuPC9/view?usp=sharing', 'published_by': '', 'department': 'CENTRAL COMPUTER CENTER'}, {'date': '08-08-2025', 'title': 'Notice-Community Internship for third semester students', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?Rk+Ht07FnwYTdxgh9d2B0RydF6rQe3R01l/UEoEfGhRUc/hKBcvIGe3ulrFs0ki03+xl4riCVjXskGymZ4Tyomi5jK1cVq4mOxWz7B6jA/1IduBJIGzAYbNpAzr2xVZB4UeffY+X05SbW9s0tWF0CGj2XhvubUtKYgP2o7A2Y0V6jzqqDSdjt+4mWU/LYP460wkc2Mlz1eP88g/S12yYHiRrpxVT/y7BdesVPYCmtto=', 'published_by': 'PREETI KAUR', 'department': 'COMPUTER SCIENCE AND ENGINEERING'}, {'date': '07-08-2025', 'title': 'NOTIFICATION-II (REJECTED) DELHI HIGHER & TECHNICAL EDUCATION SUPPORT SCHEME SCHOLARSHIP', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?Oc5OYQqv8l6gpdx+gXVxwZXW4nzOX2iskK38zFIc7avR4LvGIb9Kj+sRp37EHcPZljqT2LdEQ2YcoD0WkUZChCvPH58CDYWMFgzYpLXQDiY1NuheOP8j4q085iqFa5TlPng+TfimtjAAlPgkjhvvAdGIdMZgtgiEEugUR4oolP0q7xDLtq679VQmVpP6ITCa3Vw8K///Y2CytJ0vS53UlA==', 'published_by': 'TARUNA TIWARI', 'department': 'ACADEMIC SECTION'}, {'date': '07-08-2025', 'title': 'NOTIFICATION-I (DISCREPANCY) DELHI HIGHER & TECHNICAL EDUCATION SUPPORT SCHEME SCHOLARSHIP', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?Ru4Ivbw1GuPSNjST0mp/TiWjsyHIRgM3169DDxh6sOFECPaci2rHFK8/ijG7Es7apOAj2LGC7suzen5BeBHf4+D4Cpwp3yCc/BMMe9rBLAt/yFogiagKh/zf+n/2hzC1xUxN8QngCT9gGpAIJEZ1YRREEXHV/vhwhOtx+wJJEFgZLSCuVPPbRulbJA6KfNxbTw/frZVwQ6P3q8l71klAUg==', 'published_by': 'TARUNA TIWARI', 'department': 'ACADEMIC SECTION'}, {'date': '07-08-2025', 'title': 'Admission Cancellation of newly admitted students who have neither reported nor paid the Balance Fee (2025-26)', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?', 'published_by': 'TARUN KUMAR RAWAT', 'department': 'ADMISSION OFFICE'}, {'date': '06-08-2025', 'title': 'Submission of BTP-I (ECAM-1 & 2 )Consent form for the academic session 2025-2026', 'notice_url': 'https://www.imsnsit.org/imsnsit/plum_url.php?0c3E6dMhkLYnpFVkgrsETAzeU5EKsT++PDXoBJAdNvrWluQV7iEy+zDzd25hT5Xbrd9VbkqA7wJsvuZxNRVx8zMkoFianlAsLzQT32mWVZrmVxN3anOVtpuPKsXO8CMNWdbN0nEREVIv8VdhHZrC8N+qYk6qKDEgh4/VeqyKIW8qmfaSzpKwM/s4twlRr6t39GoBhd8+fd ...

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb+srv://admin:asdf%401234@ping.uskhf3w.mongodb.net/")
mydb = myclient["learnDB"]
mycol = mydb["Notices"]
# mycol.create_index("notice_url", unique=True)


for notice in scraped_notices:
    # x = mycol.insert_many(notice)
    try:
        x = mycol.insert_one(notice)
        print(x.inserted_id)
    except Exception as e:
        print("[W]:" , e)
        break
#print list of the _id values of the inserted documents:
# Out:
# [W]: E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c3f048a80f8aeeaa39b') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: learnDB.Notices index: _id_ dup key: { _id: ObjectId('68989c3f048a80f8aeeaa39b') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('68989c3f048a80f8aeeaa39b')}}
